# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2023.5.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
#static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"
static_url="https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
response=requests.get(static_url)
# assign the response to a object
#obj=response.json()

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup=BeautifulSoup(response.text)

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
html_tables=soup.find_all('table')
# Assign the result to a list called `html_tables`

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable" style="width:100%; font-size:1.00em; line-height:1.5em;">
# <tbody><tr class="is-sticky">
# <th scope="col" style="width: 10%;">Date and time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_26-2"><a href="#cite_note-booster-26">[c]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_27-2"><a href="#cite_note-Dragon-27">[d]</a></sup>
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th></tr>
# <tr>
# <td rowspan="2">Was July 2024 before mishap investigation<sup class="reference" id="cite_ref-nextSFupcoming_386-1"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 10–4</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">Was July 2024 before mishap investigation<sup class="reference" id="cite_ref-387"><a href="#cite_note-387">[379]</a></sup><sup class="reference" id="cite_ref-388"><a href="#cite_note-388">[380]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 1</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10A),<sup class="reference" id="cite_ref-389"><a href="#cite_note-389">[381]</a></sup> <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 2</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10B)
# </td>
# <td><a href="/wiki/Highly_elliptical_orbit" title="Highly elliptical orbit">HEO</a>
# </td>
# <td><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> / <a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> will launch 2 satellites of the <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">Arctic Satellite Broadband Mission</a> (ASBM) system into highly elliptical orbits (apogee: 43,509 km (27,035 mi), perigee: 8,089 km (5,026 mi), 63.4° inclination)<sup class="reference" id="cite_ref-390"><a href="#cite_note-390">[382]</a></sup> to provide communication coverage to high latitudes not served by geosynchronous satellites.<sup class="reference" id="cite_ref-391"><a href="#cite_note-391">[383]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Was July 2024 before mishap investigation<sup class="reference" id="cite_ref-nextSFupcoming_386-2"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 10–5</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">Was July 2024 before mishap investigation<sup class="reference" id="cite_ref-nextSFupcoming_386-3"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/> <a class="mw-redirect" href="/wiki/SLC-4E" title="SLC-4E">SLC-4E</a>
# </td>
# <td><i><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXTransporter11" title="List of spaceflight launches in July–December 2024">Transporter-11</a></i>, SmallSat Rideshare<sup class="reference" id="cite_ref-spacex-smallsat_307-2"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">Was July 2024 before mishap investigation<sup class="reference" id="cite_ref-392"><a href="#cite_note-392">[384]</a></sup><sup class="reference" id="cite_ref-393"><a href="#cite_note-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺<br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1083" title="List of Falcon 9 first-stage boosters">B1083.4</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Polaris_Dawn" title="Polaris Dawn">Polaris Dawn</a><sup class="reference" id="cite_ref-394"><a href="#cite_note-394">[386]</a></sup><br/>(<a href="/wiki/Crew_Dragon_Resilience" title="Crew Dragon Resilience">Crew Dragon C207.3 <i>Resilience</i></a> ♺ )
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Jared_Isaacman" title="Jared Isaacman">Jared Isaacman</a> / <a href="/wiki/Polaris_program" title="Polaris program">Polaris Program</a>
# </td></tr>
# <tr>
# <td colspan="5">First of two <a href="/wiki/SpaceX_Dragon_2" title="SpaceX Dragon 2">Crew Dragon</a> missions for the Polaris Program. Crew will consist of <a href="/wiki/Jared_Isaacman" title="Jared Isaacman">Jared Isaacman</a>, <a href="/wiki/Scott_Poteet" title="Scott Poteet">Scott Poteet</a>, <a href="/wiki/Sarah_Gillis" title="Sarah Gillis">Sarah Gillis</a> and <a href="/wiki/Anna_Menon" title="Anna Menon">Anna Menon</a> and will spend up to five days in orbit. Flying higher than any crewed Earth orbiting spacecraft has ever flown, Polaris Dawn will conduct research with the aim of better understanding the effects of spaceflight and space radiation on human health. At approximately 500 kilometers above the Earth, the crew will attempt the first-ever commercial extravehicular activity (EVA) with SpaceX-designed EVA spacesuits, derived from the existing intravehicular (IVA) suit.
# </td></tr>
# <tr>
# <td rowspan="2">Was 3 August 2024 before mishap investigation
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Cygnus_NG-21" title="Cygnus NG-21">CRS NG-21</a> (<a href="/wiki/Cygnus_(spacecraft)" title="Cygnus (spacecraft)">Cygnus (enhanced)</a>)<sup class="reference" id="cite_ref-395"><a href="#cite_note-395">[387]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Second of three launches Northrop Grumman acquired from SpaceX while a replacement engine is developed for its Antares rocket.
# </td></tr>
# <tr>
# <td rowspan="2">Was mid August 2024 before mishap investigation<sup class="reference" id="cite_ref-396"><a href="#cite_note-396">[388]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> <br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1085" title="List of Falcon 9 first-stage boosters">B1085.1</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/SpaceX_Crew-9" title="SpaceX Crew-9">Crew-9</a><sup class="reference" id="cite_ref-NASACREW7-9_189-2"><a href="#cite_note-NASACREW7-9-189">[181]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/ISS_Crew_Transportation_Services" title="ISS Crew Transportation Services">CTS</a>)<sup class="reference" id="cite_ref-CCD6_85-5"><a href="#cite_note-CCD6-85">[77]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">After first six <a class="mw-redirect" href="/wiki/Crew_Dragon" title="Crew Dragon">Crew Dragon</a> launches of NASA <a class="mw-redirect" href="/wiki/Commercial_Crew_Development" title="Commercial Crew Development">USCV</a> award, a further three missions for SpaceX were announced on 3 December 2021. These launches carry up to four astronauts and 100 kg (220 lb) of cargo to the ISS as well as feature a lifeboat function to evacuate astronauts from ISS in case of an emergency.<sup class="reference" id="cite_ref-CCD6_85-6"><a href="#cite_note-CCD6-85">[77]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Was August 2024 before mishap investigation<sup class="reference" id="cite_ref-nextSFupcoming_386-4"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup><sup class="reference" id="cite_ref-shephard14224_397-0"><a href="#cite_note-shephard14224-397">[389]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_341-2"><a href="#cite_note-worldviewlegion-341">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_398-0"><a href="#cite_note-WorldView-Legion_1,_...,_6-398">[390]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 3–4</a> Mission 2 (2 sats)<sup class="reference" id="cite_ref-spacenews.com_399-0"><a href="#cite_note-spacenews.com-399">[391]</a></sup><sup class="reference" id="cite_ref-SN240423_400-0"><a href="#cite_note-SN240423-400">[392]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_401-0"><a href="#cite_note-worldviewLegion10QSept22-401">[393]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">Was August 2024 before mishap investigation<sup class="reference" id="cite_ref-sn-20240102_402-0"><a href="#cite_note-sn-20240102-402">[394]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/GSAT-20" title="GSAT-20">GSAT-20</a><sup class="reference" id="cite_ref-NSIL_403-0"><a href="#cite_note-NSIL-403">[395]</a></sup> (CMS-03)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/New_Space_India_Limited" title="New Space India Limited">New Space India Limited</a><sup class="reference" id="cite_ref-NSIL_403-1"><a href="#cite_note-NSIL-403">[395]</a></sup><br/><a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a><sup class="reference" id="cite_ref-404"><a href="#cite_note-404">[396]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">Indian telecommunications satellite for <a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a>. Originally planned to launch on <a href="/wiki/ISRO" title="ISRO">ISRO</a>'s <a href="/wiki/LVM3" title="LVM3">LVM3</a>,<sup class="reference" id="cite_ref-annualreport2018_405-0"><a href="#cite_note-annualreport2018-405">[397]</a></sup> but later shifted to <a href="/wiki/Falcon_9" title="Falcon 9">Falcon 9</a> due to mass and scheduling issues.<sup class="reference" id="cite_ref-sn-20240102_402-1"><a href="#cite_note-sn-20240102-402">[394]</a></sup> It will be the first ISRO-made satellite to move from <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a> to <a href="/wiki/Geostationary_orbit" title="Geostationary orbit">geostationary orbit</a> using electric propulsion.<sup class="reference" id="cite_ref-thewire_406-0"><a href="#cite_note-thewire-406">[398]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Was ~13 September 2024 before mishap investigation<sup class="reference" id="cite_ref-Galileo_407-0"><a href="#cite_note-Galileo-407">[399]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td>2× <a href="/wiki/Galileo_(satellite_navigation)" title="Galileo (satellite navigation)">Galileo</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Medium_Earth_Orbit" title="Medium Earth Orbit">MEO</a>
# </td>
# <td><a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Second launch of Galileo satellites.
# </td></tr>
# <tr>
# <td rowspan="2">Was September 2024 before mishap investigation<sup class="reference" id="cite_ref-408"><a href="#cite_note-408">[400]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/SpaceX_CRS-31" title="SpaceX CRS-31">SpaceX CRS-31</a><sup class="reference" id="cite_ref-March2022CRS2_319-1"><a href="#cite_note-March2022CRS2-319">[311]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Six additional <a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS-2</a> missions for Dragon 2 were announced in March 2022, resupplying the ISS until 2026.
# </td></tr>
# <tr>
# <td rowspan="2">Was September 2024 before mishap investigation<sup class="reference" id="cite_ref-DoD28222_409-0"><a href="#cite_note-DoD28222-409">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-B</a><sup class="reference" id="cite_ref-SSCA12_410-0"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Was Q3 2024 before mishap investigation<sup class="reference" id="cite_ref-411"><a href="#cite_note-411">[403]</a></sup><sup class="reference" id="cite_ref-412"><a href="#cite_note-412">[404]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">MicroGEO</a> (4 satellites)<sup class="reference" id="cite_ref-astranis-microgeo-f9_413-0"><a href="#cite_note-astranis-microgeo-f9-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_orbit" title="Geostationary orbit">GEO</a>
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">Astranis</a>
# </td></tr>
# <tr>
# <td colspan="5">Dedicated Falcon 9 launch to put four Astranis MicroGEO communications satellites into service in 2023.<sup class="reference" id="cite_ref-astranis-microgeo-f9_413-1"><a href="#cite_note-astranis-microgeo-f9-413">[405]</a></sup> The MicroGEOs will be launched to a custom geostationary orbit, with the four satellites individually conducting on-orbit maneuvers to inject themselves into their orbital slots. However, it is unclear whether this will be a direct to <a href="/wiki/Geostationary_orbit" title="Geostationary orbit">geostationary orbit</a> insertion, or an optimized <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a>. The four spacecraft will be mounted to a standard adapter ring, known as an <a href="/wiki/EELV_Secondary_Payload_Adapter" title="EELV Secondary Payload Adapter">ESPA-Grande</a>, for ease of deployment.
# </td></tr>
# <tr>
# <td rowspan="2">Was Q3 2024 before mishap investigation<sup class="reference" id="cite_ref-nextSFupcoming_386-5"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup><sup class="reference" id="cite_ref-Rainbow_414-0"><a href="#cite_note-Rainbow-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td>BlueBird Block 1 (5 Satellites)<sup class="reference" id="cite_ref-AST_SpaceMobile_delays_commercial_s_415-0"><a href="#cite_note-AST_SpaceMobile_delays_commercial_s-415">[407]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/AST_SpaceMobile" title="AST SpaceMobile">AST SpaceMobile</a>
# </td></tr>
# <tr>
# <td colspan="5">Cellphone-compatible broadband constellation. Each satellite is to be a similar size and weight to its 1,500-kilogram BlueWalker 3 prototype and have a 64 square meter phased array antenna.
# </td></tr>
# <tr>
# <td rowspan="2">Late Q3 / Early Q4 2024<sup class="reference" id="cite_ref-416"><a href="#cite_note-416">[408]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Blue_Ghost" title="Blue Ghost">Blue Ghost</a> M1<sup class="reference" id="cite_ref-417"><a href="#cite_note-417">[409]</a></sup><sup class="reference" id="cite_ref-418"><a href="#cite_note-418">[410]</a></sup>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a><br/>NASA (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a> has selected <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>'s Falcon 9 rocket to deliver the Blue Ghost lunar lander to the lunar surface.<sup class="reference" id="cite_ref-419"><a href="#cite_note-419">[411]</a></sup> Blue Ghost will carry 10 payloads for NASA's <a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">Commercial Lunar Payload Services</a> task order 19D mission along with other separately contracted payloads.<sup class="reference" id="cite_ref-420"><a href="#cite_note-420">[412]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Was 8 October 2024 before mishap investigation<sup class="reference" id="cite_ref-sn-20221020_157-1"><a href="#cite_note-sn-20221020-157">[149]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Hera_(space_mission)" title="Hera (space mission)">Hera</a> with Juventas and Milani
# </td>
# <td><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Hera is a space mission in development at the <a href="/wiki/European_Space_Agency" title="European Space Agency">European Space Agency</a> in its Space Safety program. Its primary objective is to study the <a href="/wiki/65803_Didymos" title="65803 Didymos">Didymos binary asteroid system</a> that was impacted by <a href="/wiki/Double_Asteroid_Redirection_Test" title="Double Asteroid Redirection Test">DART</a> and contribute to validation of the <a href="/wiki/Kinetic_energy" title="Kinetic energy">kinetic</a> impact method to deviate a <a href="/wiki/Near-Earth_object" title="Near-Earth object">near-Earth asteroid</a> in a colliding trajectory with Earth. It will measure the size and the morphology of the crater created by and momentum transferred by an artificial projectile impacting an asteroid, which will allow measuring the efficiency of the deflection produced by the impact. It will also carry two <a href="/wiki/Small_satellite" title="Small satellite">nano-satellite</a> CubeSats, called <i>Milani</i> and <i>Juventas</i>.
# </td></tr>
# <tr>
# <td rowspan="4">Was 10 October 2024 before mishap investigation<sup class="reference" id="cite_ref-421"><a href="#cite_note-421">[413]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">B1090 (core)</a>
# </td>
# <td rowspan="3"><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td rowspan="3"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a>
# </td>
# <td rowspan="3"><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td rowspan="3"><a href="/wiki/NASA" title="NASA">NASA</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1064" title="List of Falcon 9 first-stage boosters">B1064.6 ♺ (side)</a><sup class="reference" id="cite_ref-arstechpsyche20230829_422-0"><a href="#cite_note-arstechpsyche20230829-422">[414]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1065" title="List of Falcon 9 first-stage boosters">B1065.6 ♺ (side)</a><sup class="reference" id="cite_ref-arstechpsyche20230829_422-1"><a href="#cite_note-arstechpsyche20230829-422">[414]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a> will conduct a detailed survey of <a href="/wiki/Europa_(moon)" title="Europa (moon)">Europa</a> and use a sophisticated suite of science instruments to investigate whether the icy moon has conditions suitable for life. Key mission objectives are to produce high-resolution images of Europa's surface, determine its composition, look for signs of recent or ongoing geological activity, measure the thickness of the moon's icy shell, search for subsurface lakes, and determine the depth and salinity of Europa's ocean.<sup class="reference" id="cite_ref-NASA_EC_L_423-0"><a href="#cite_note-NASA_EC_L-423">[415]</a></sup> The mission will fly past Mars and Earth before arriving at Jupiter in April 2030.<sup class="reference" id="cite_ref-424"><a href="#cite_note-424">[416]</a></sup><sup class="reference" id="cite_ref-425"><a href="#cite_note-425">[417]</a></sup> The side boosters and the center core will all be expended.
# </td></tr>
# <tr>
# <td rowspan="2">Was October 2024 before mishap investigation<sup class="reference" id="cite_ref-spacex-smallsat_307-3"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CC</a>
# </td>
# <td><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXTransporter12" title="List of spaceflight launches in July–December 2024"><i>Transporter-12</i></a>, SmallSat Rideshare
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">Was October 2024 before mishap investigation<sup class="reference" id="cite_ref-DoD28222_409-1"><a href="#cite_note-DoD28222-409">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-C</a><sup class="reference" id="cite_ref-SSCA12_410-1"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Was October 2024 before mishap investigation<sup class="reference" id="cite_ref-426"><a href="#cite_note-426">[418]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Axiom_Mission_4" title="Axiom Mission 4">Ax-4</a><sup class="reference" id="cite_ref-axiom_132-2"><a href="#cite_note-axiom-132">[124]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Axiom_Space" title="Axiom Space">Axiom Space</a>
# </td></tr>
# <tr>
# <td colspan="5">Contract for 3 additional missions was signed in June 2021.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-atalayar-20240422_427-0"><a href="#cite_note-atalayar-20240422-427">[419]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Spainsat_NG" title="Spainsat NG">Spainsat-NG I</a><sup class="reference" id="cite_ref-hisdesat-20221107_428-0"><a href="#cite_note-hisdesat-20221107-428">[420]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Hisdesat" title="Hisdesat">Hisdesat</a>
# </td></tr>
# <tr>
# <td colspan="5">Communications satellite built on the <a href="/wiki/Eurostar_(satellite_bus)" title="Eurostar (satellite bus)">Eurostar-Neo</a> platform, to be utilized by the Spanish government and its allies.<sup class="reference" id="cite_ref-:7_429-0"><a href="#cite_note-:7-429">[421]</a></sup> First of two launches for the Spainsat-NG program.
# </td></tr>
# <tr>
# <td rowspan="4">November 2024<sup class="reference" id="cite_ref-430"><a href="#cite_note-430">[422]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">B10??.1 (core)</a>
# </td>
# <td rowspan="3"><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td rowspan="3"><a class="mw-redirect" href="/wiki/Griffin_Mission_1" title="Griffin Mission 1">Griffin Mission 1</a><sup class="reference" id="cite_ref-431"><a href="#cite_note-431">[423]</a></sup>
# </td>
# <td rowspan="3"><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td rowspan="3"><a class="mw-redirect" href="/wiki/Astrobotic" title="Astrobotic">Astrobotic</a><br/>NASA (<a href="/wiki/Artemis_program" title="Artemis program">Artemis</a>)
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1072" title="List of Falcon 9 first-stage boosters">B1072.2 (side)</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1086" title="List of Falcon 9 first-stage boosters">B1086.2 (side)</a>
# </td></tr>
# <tr>
# <td colspan="5">Astrobotic's <a class="mw-redirect" href="/wiki/Griffin_(spacecraft)" title="Griffin (spacecraft)">Griffin lunar lander</a> was expected to deliver NASA's <i><a href="/wiki/VIPER_(rover)" title="VIPER (rover)">VIPER</a></i> spacecraft to the <a href="/wiki/Lunar_south_pole" title="Lunar south pole">lunar south pole</a>, but this is now extremely unlikely.<sup class="reference" id="cite_ref-432"><a href="#cite_note-432">[424]</a></sup> Booster recovery method is unconfirmed, but could possibly feature the first Falcon Heavy center core recovery attempt since <a class="mw-redirect" href="/wiki/STP-2" title="STP-2">STP-2</a>.<sup class="reference" id="cite_ref-433"><a href="#cite_note-433">[425]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">November 2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td><i><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXBandwagon2" title="List of spaceflight launches in July–December 2024">Bandwagon-2</a></i>, SmallSat Rideshare<sup class="reference" id="cite_ref-spacex-smallsat_307-4"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup><sup class="reference" id="cite_ref-BandW_329-1"><a href="#cite_note-BandW-329">[321]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to 45 degree inclination 550–600 km altitude.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-DoD28222_409-2"><a href="#cite_note-DoD28222-409">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-D</a><sup class="reference" id="cite_ref-SSCA12_410-2"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td>425 Project SAR satellite flight 3<sup class="reference" id="cite_ref-yonhap8124_434-0"><a href="#cite_note-yonhap8124-434">[426]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>?
# </td>
# <td><a href="/wiki/Republic_of_Korea_Armed_Forces" title="Republic of Korea Armed Forces">Republic of Korea Armed Forces</a>
# </td></tr>
# <tr>
# <td colspan="5">A military satellite of South Korea with a mass of ~800 kg. Expected to be a part of Bandwagon-2.<sup class="reference" id="cite_ref-435"><a href="#cite_note-435">[427]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">December 2024<sup class="reference" id="cite_ref-DoD28222_409-3"><a href="#cite_note-DoD28222-409">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-E</a><sup class="reference" id="cite_ref-SSCA12_410-3"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-DoD28222_409-4"><a href="#cite_note-DoD28222-409">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Transport layer T1TR-C</a><sup class="reference" id="cite_ref-SSCA12_410-4"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-sn-20240213_436-0"><a href="#cite_note-sn-20240213-436">[428]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-437"><a href="#cite_note-437">[429]</a></sup>
# </td>
# <td><a href="/wiki/IM-2" title="IM-2">IM-2</a> <i><a class="mw-redirect" href="/wiki/Nova-C" title="Nova-C">Nova-C</a></i> lunar lander<br/><a href="/wiki/SHERPA_(space_tug)" title="SHERPA (space tug)">Sherpa-ES</a>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)<br/><a href="/wiki/Intuitive_Machines" title="Intuitive Machines">Intuitive Machines</a><br/><a href="/wiki/Spaceflight,_Inc." title="Spaceflight, Inc.">Spaceflight, Inc.</a>
# </td></tr>
# <tr>
# <td colspan="5">Intuitive Machines is sending its second lander aboard a SpaceX Falcon 9, with a projected launch time frame in late 2024. In February 2024, Intuitive Machines has completed its first lander mission via SpaceX, which is also hosting payloads for other private companies seeking to make lunar landfall under NASA's Commercial Lunar Payload Services program. NASA's <a href="/wiki/PRIME-1" title="PRIME-1">PRIME-1</a> is expected to be included.<sup class="reference" id="cite_ref-438"><a href="#cite_note-438">[430]</a></sup> The Sherpa-ES <i>Go Beyond</i> orbital transfer vehicle will deploy rideshare payloads to trans-lunar orbit, low-lunar orbit and beyond to GEO.<sup class="reference" id="cite_ref-439"><a href="#cite_note-439">[431]</a></sup><sup class="reference" id="cite_ref-440"><a href="#cite_note-440">[432]</a></sup><sup class="reference" id="cite_ref-441"><a href="#cite_note-441">[433]</a></sup> NASA's <a href="/wiki/Lunar_Trailblazer" title="Lunar Trailblazer">Lunar Trailblazer</a> mission will fly as a secondary payload on this mission.<sup class="reference" id="cite_ref-442"><a href="#cite_note-442">[434]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-443"><a href="#cite_note-443">[435]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Koreasat" title="Koreasat">Koreasat</a> 6A<sup class="reference" id="cite_ref-444"><a href="#cite_note-444">[436]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/KT_Corporation" title="KT Corporation">KT Sat</a>
# </td></tr>
# <tr>
# <td colspan="5">South Korean communications satellite built on the <a href="/wiki/Spacebus" title="Spacebus">Spacebus-4000B2</a> platform. To be positioned at 116° East.<sup class="reference" id="cite_ref-445"><a href="#cite_note-445">[437]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-nextSFupcoming_386-6"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup><sup class="reference" id="cite_ref-SFPR9321_446-0"><a href="#cite_note-SFPR9321-446">[438]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a><sup class="reference" id="cite_ref-ussf36config_447-0"><a href="#cite_note-ussf36config-447">[439]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-ussf36location_448-0"><a href="#cite_note-ussf36location-448">[440]</a></sup>
# </td>
# <td>USSF-36
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_449-0"><a href="#cite_note-defense.gov-449">[441]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-O3b_Nov23_450-0"><a href="#cite_note-O3b_Nov23-450">[442]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/O3b_mPOWER" title="O3b mPOWER">O3b mPOWER</a> 7 &amp; 8
# </td>
# <td><a href="/wiki/Medium_Earth_orbit" title="Medium Earth orbit">MEO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td></tr>
# <tr>
# <td colspan="5">In August 2020, SES expanded the O3b mPOWER contract with two additional launches, raising the number of satellites from 7 to 11 satellites at nearly 2 tons each.<sup class="reference" id="cite_ref-451"><a href="#cite_note-451">[443]</a></sup><sup class="reference" id="cite_ref-businesswire.com_452-0"><a href="#cite_note-businesswire.com-452">[444]</a></sup> In October 2023 the mission was delayed to the second half of 2024 due to electrical issues discovered in the first four satellites of the constellation.<sup class="reference" id="cite_ref-O3b_Nov23_450-1"><a href="#cite_note-O3b_Nov23-450">[442]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-shephard14224_397-1"><a href="#cite_note-shephard14224-397">[389]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_341-3"><a href="#cite_note-worldviewlegion-341">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_398-1"><a href="#cite_note-WorldView-Legion_1,_...,_6-398">[390]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-nextSFupcoming_386-7"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 5 &amp; 6</a> Mission 3 (2 sats)<sup class="reference" id="cite_ref-spacenews.com_399-1"><a href="#cite_note-spacenews.com-399">[391]</a></sup><sup class="reference" id="cite_ref-SN240423_400-1"><a href="#cite_note-SN240423-400">[392]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_401-1"><a href="#cite_note-worldviewLegion10QSept22-401">[393]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-nextSFupcoming_386-8"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup><sup class="reference" id="cite_ref-SFPR9321_446-1"><a href="#cite_note-SFPR9321-446">[438]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a><sup class="reference" id="cite_ref-ussf36config_447-1"><a href="#cite_note-ussf36config-447">[439]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td>NROL-69
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_449-1"><a href="#cite_note-defense.gov-449">[441]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Late 2024<sup class="reference" id="cite_ref-453"><a href="#cite_note-453">[445]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara#Nusantara_Lima" title="PT Pasifik Satelit Nusantara">Nusantara Lima</a><sup class="reference" id="cite_ref-454"><a href="#cite_note-454">[446]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>?
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara" title="PT Pasifik Satelit Nusantara">PT Pasifik Satelit Nusantara</a>
# </td></tr>
# <tr>
# <td colspan="5">A hot backup system for <a href="/wiki/PT_Pasifik_Satelit_Nusantara#SATRIA-1" title="PT Pasifik Satelit Nusantara">SATRIA-1</a>.<sup class="reference" id="cite_ref-455"><a href="#cite_note-455">[447]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-nextSFupcoming_386-9"><a href="#cite_note-nextSFupcoming-386">[378]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Doge-1" title="Doge-1">DOGE-1</a> <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td>Geometric Energy
# </td></tr>
# <tr>
# <td colspan="5">Originally expected to be a secondary rideshare payload on <a href="/wiki/IM-1" title="IM-1">IM-1</a> mission but the 40 kg was later postponed to a later date due to incomplete radio and launch requirements.&gt;<sup class="reference" id="cite_ref-456"><a href="#cite_note-456">[448]</a></sup><sup class="noprint Inline-Template noprint Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:No_original_research#Primary,_secondary_and_tertiary_sources" title="Wikipedia:No original research"><span title="This claim needs references to reliable secondary sources. (February 2024)">non-primary source needed</span></a></i>]</sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-ispr25122_457-0"><a href="#cite_note-ispr25122-457">[449]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td>Unknown
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a> 2nd lunar lander<sup class="reference" id="cite_ref-458"><a href="#cite_note-458">[450]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Trans_Lunar_Injection" title="Trans Lunar Injection">TLI</a>
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>
# </td></tr>
# <tr>
# <td colspan="5">Second lunar lander built by Japanese company <a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>.
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-459"><a href="#cite_note-459">[451]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Thuraya#Satellites" title="Thuraya">Thuraya 4-NGS</a>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Thuraya" title="Thuraya">Thuraya</a>
# </td></tr>
# <tr>
# <td colspan="5">Planned replacement for Thuraya 2.<sup class="reference" id="cite_ref-460"><a href="#cite_note-460">[452]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Cygnus_NG-22" title="Cygnus NG-22">CRS NG-22</a> (<a href="/wiki/Cygnus_(spacecraft)" title="Cygnus (spacecraft)">Cygnus (enhanced)</a>)<sup class="reference" id="cite_ref-NG_RepAnt_283-1"><a href="#cite_note-NG_RepAnt-283">[275]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Third of three launches Northrop Grumman acquired from SpaceX while a replacement engine is developed for its Antares rocket.
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td>Unknown
# </td>
# <td>Reentry demonstration capsule <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/The_Exploration_Company" title="The Exploration Company">The Exploration Company</a>
# </td></tr>
# <tr>
# <td colspan="5">1600 kg 2.5 metre diameter reduced scale test of a reentry capsule, the full-scale version Nyx (4 metre diameter 8000 kg) is planned to deliver payloads to the ISS and return them back to Earth.<sup class="reference" id="cite_ref-461"><a href="#cite_note-461">[453]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024?
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td>USSF-31<sup class="reference" id="cite_ref-SSCA12_410-5"><a href="#cite_note-SSCA12-410">[402]</a></sup>
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Classified mission, part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
thelements=first_launch_table.find_all('th')
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
for k in thelements:
    name=extract_column_from_header(k)
    # Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
    if name is not None and len(name)>0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Date and time ( )', 'Launch site', 'Payload', 'Orbit', 'Customer']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table 
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            print(flight_number)
            launch_dict['Flight No.'].append(flight_number)
            datatimelist=date_time(row[0])
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            print(date)
            launch_dict['Date'].append(date)
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            print(time)
            launch_dict['Time'].append(time)
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            print(bv)
            launch_dict['Version Booster'].append(bv)
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            print(launch_site)
            launch_dict['Launch site'].append(launch_site)
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            if row[3].a!=None:
                payload = row[3].a.string
                print(payload)
                launch_dict['Payload'].append(payload)
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            print(payload)
            launch_dict['Payload mass'].append(payload_mass)
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            print(orbit)
            launch_dict['Orbit'].append(orbit)
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            if row[6].a!= None:
                customer = row[6].a
                print(customer)
                launch_dict['Customer'].append(customer)
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            print(launch_outcome)
            launch_dict['Launch outcome'].append(launch_outcome)
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            print(booster_landing)
            launch_dict['Booster landing'].append(booster_landing)
# Out:
# 195
# 3 January 2023
# 14:56
# F9 B5B1060.15
# CCSFS
# None
# None
# SSO
# Success
#
# Success
# 196
# 10 January 2023
# 04:50
# F9 B5
# CCSFS
# OneWeb
# OneWeb
# Polar
# <a class="mw-redirect" href="/wiki/OneWeb" title="OneWeb">OneWeb</a>
# Success
#
# Success
# 197
# 18 January 2023
# 12:24
# F9 B5
# CCSFS
# USA-343
# USA-343
# MEO
# <a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# Success
#
# Success
# 198
# 19 January 2023
# 15:43
# F9 B5
# VSFB
# Starlink Group 2–4
# Starlink Group 2–4
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 199
# 26 January 2023
# 09:32
# F9 B5
# CCSFS
# Starlink Group 5-2
# Starlink Group 5-2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 200
# 31 January 2023
# 16:15
# F9 B5B1071.7
# VSFB
# Starlink Group 2–6
# Starlink Group 2–6
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 201
# 2 February 2023
# 07:58
# F9 B5
# KSC
# Starlink Group 5-3
# Starlink Group 5-3
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 202
# 7 February 2023
# 01:32
# F9 B5B1073.6
# CCSFS
# Amazonas Nexus
# Amazonas Nexus
# GTO
# <a href="/wiki/Hispasat" title="Hispasat">Hispasat</a>
# Success
#
# Success
# 203
# 12 February 2023
# 05:10
# F9 B5B1062.12
# CCSFS
# Starlink Group 5-4
# Starlink Group 5-4
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 204
# 17 February 2023
# 19:12
# F9 B5B1063.9
# VSFB
# Starlink Group 2–5
# Starlink Group 2–5
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 205
# 18 February 2023
# 03:59
# F9 B5B1077.3
# CCSFS
# Inmarsat-6 F2
# Inmarsat-6 F2
# GTO
# <a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# Success
#
# Success
# 206
# 27 February 2023
# 23:13
# F9 B5B1076.3
# CCSFS
# Starlink Group 6-1
# Starlink Group 6-1
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 207
# 2 March 2023
# 05:34
# F9 B5
# KSC
# Crew-6
# Crew-6
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 208
# 3 March 2023
# 18:38
# F9 B5
# VSFB
# Starlink Group 2–7
# Starlink Group 2–7
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 209
# 9 March 2023
# 19:13
# F9 B5
# CCSFS
# OneWeb #17
# OneWeb #17
# LEO
# <a class="mw-redirect" href="/wiki/OneWeb" title="OneWeb">OneWeb</a>
# Success
#
# Success
# 210
# 15 March 2023
# 00:30
# F9 B5B1073.7
# KSC
# SpaceX CRS-27
# SpaceX CRS-27
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 211
# 17 March 2023
# 19:26
# F9 B5
# VSFB
# Starlink Group 2–8
# Starlink Group 2–8
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 212
# 17 March 2023
# 23:38
# F9 B5
# CCSFS
# SES-18 and SES-19
# SES-18 and SES-19
# GTO
# <a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# Success
#
# Success
# 213
# 24 March 2023
# 15:43
# F9 B5
# CCSFS
# Starlink Group 5-5
# Starlink Group 5-5
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 214
# 29 March 2023
# 20:01
# F9 B5
# CCSFS
# Starlink Group 5–10
# Starlink Group 5–10
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 215
# 2 April 2023
# 14:29
# F9 B5
# VSFB
# Transport and Tracking Layer (Tranche 0A)
# Transport and Tracking Layer (Tranche 0A)
# LEO
# <a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# Success
#
# Success
# 216
# 7 April 2023
# 04:30
# F9 B5
# CCSFS
# Intelsat 40e
# Intelsat 40e
# GTO
# <a href="/wiki/Intelsat" title="Intelsat">Intelsat</a>
# Success
#
# Success
# 217
# 15 April 2023
# 06:47
# F9 B5
# VSFB
# Transporter-7: (51 payloads Smallsat Rideshare)
# Transporter-7: (51 payloads Smallsat Rideshare)
# SSO
# Success
#
# Success
# 218
# 19 April 2023
# 14:31
# F9 B5
# CCSFS
# Starlink Group 6-2
# Starlink Group 6-2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 219
# 27 April 2023
# 13:40
# F9 B5
# VSFB
# Starlink Group 3–5
# Starlink Group 3–5
# SSO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 220
# 28 April 2023
# 22:12
# F9 B5B1078.2
# CCSFS
# O3b mPOWER
# O3b mPOWER
# MEO
# <a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# Success
#
# Success
# 221
# 4 May 2023
# 07:31
# F9 B5B1069.7
# CCSFS
# Starlink Group 5–6
# Starlink Group 5–6
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 222
# 10 May 2023
# 20:09
# F9 B5B1075.3
# VSFB
# Starlink Group 2–9
# Starlink Group 2–9
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 223
# 14 May 2023
# 05:03
# F9 B5
# CCSFS
# Starlink Group 5–9
# Starlink Group 5–9
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 224
# 19 May 2023
# 06:19
# F9 B5
# CCSFS
# Starlink Group 6-3
# Starlink Group 6-3
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 225
# 20 May 2023
# 13:16
# F9 B5
# VSFB
# Iridium-NEXT
# Iridium-NEXT
# Polar
# <a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium</a>
# Success
#
# Success
# 226
# 21 May 2023
# 21:37
# F9 B5
# KSC
# Ax-2
# Ax-2
# LEO
# <a href="/wiki/Axiom_Space" title="Axiom Space">Axiom Space</a>
# Success
#
# Success
# 227
# 27 May 2023
# 04:30
# F9 B5
# CCSFS
# ArabSat 7B
# ArabSat 7B
# GTO
# <a class="mw-redirect" href="/wiki/Arabsat" title="Arabsat">Arabsat</a>
# Success
#
# Success
# 228
# 31 May 2023
# 06:02
# F9 B5
# VSFB
# Starlink Group 2–10
# Starlink Group 2–10
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 229
# 4 June 2023
# 12:20
# F9 B5
# CCSFS
# Starlink Group 6-4
# Starlink Group 6-4
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 230
# 5 June 2023
# 15:47
# F9 B5B1077.5
# KSC
# SpaceX CRS-28
# SpaceX CRS-28
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 231
# 12 June 2023
# 07:10
# F9 B5
# CCSFS
# Starlink Group 5–11
# Starlink Group 5–11
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 232
# 12 June 2023
# 21:35
# F9 B5
# VSFB
# None
# None
# SSO
# Success
#
# Success
# 233
# 18 June 2023
# 22:21
# F9 B5B1067.12
# CCSFS
# SATRIA
# SATRIA
# GTO
# <a href="/wiki/PT_Pasifik_Satelit_Nusantara" title="PT Pasifik Satelit Nusantara">PT Pasifik Satelit Nusantara</a>
# Success
#
# Success
# 234
# 22 June 2023
# 07:19
# F9 B5B1075.4
# VSFB
# Starlink Group 5–7
# Starlink Group 5–7
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 235
# 23 June 2023
# 15:35
# F9 B5
# CCSFS
# Starlink Group 5–12
# Starlink Group 5–12
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 236
# 1 July 2023
# 15:12
# F9 B5
# CCSFS
# Euclid
# Euclid
# None
# <a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# Success
#
# Success
# 237
# 7 July 2023
# 19:29
# F9 B5B1063.12
# VSFB
# Starlink Group 5–13
# Starlink Group 5–13
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 238
# 10 July 2023
# 03:58
# F9 B5
# CCSFS
# Starlink Group 6-5
# Starlink Group 6-5
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 239
# 16 July 2023
# 03:50
# F9 B5B1060.16
# CCSFS
# Starlink Group 5–15
# Starlink Group 5–15
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 240
# 20 July 2023
# 04:09
# F9 B5
# VSFB
# Starlink Group 6–15
# Starlink Group 6–15
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 241
# 24 July 2023
# 00:50
# F9 B5
# CCSFS
# Starlink Group 6-6
# Starlink Group 6-6
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 242
# 28 July 2023
# 04:01
# F9 B5
# CCSFS
# Starlink Group 6–7
# Starlink Group 6–7
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 243
# 3 August 2023
# 05:00
# F9 B5
# CCSFS
# Galaxy 37
# Galaxy 37
# GTO
# <a href="/wiki/Intelsat" title="Intelsat">Intelsat</a>
# Success
#
# Success
# 244
# 7 August 2023
# 02:41
# F9 B5
# CCSFS
# Starlink Group 6–8
# Starlink Group 6–8
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 245
# 8 August 2023
# 03:57
# F9 B5
# VSFB
# Starlink Group 6–20
# Starlink Group 6–20
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 246
# 11 August 2023
# 05:17
# F9 B5
# CCSFS
# Starlink Group 6–9
# Starlink Group 6–9
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 247
# 17 August 2023
# 03:36
# F9 B5
# CCSFS
# Starlink Group 6–10
# Starlink Group 6–10
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 248
# 22 August 2023
# 09:37
# F9 B5
# VSFB
# Starlink Group 7-1
# Starlink Group 7-1
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 249
# 26 August 2023
# 07:27
# F9 B5
# KSC
# Crew-7
# Crew-7
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 250
# 27 August 2023
# 01:05
# F9 B5
# CCSFS
# Starlink Group 6–11
# Starlink Group 6–11
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 251
# 1 September 2023
# 02:21
# F9 B5
# CCSFS
# Starlink Group 6–13
# Starlink Group 6–13
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 252
# 2 September 2023
# [187]
# F9 B5
# VSFB
# Transport and Tracking Layer (Tranche 0B)
# Transport and Tracking Layer (Tranche 0B)
# LEO
# <a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# Success
#
# Success
# 253
# 4 September 2023
# 02:47
# F9 B5
# KSC
# Starlink Group 6–12
# Starlink Group 6–12
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 254
# 9 September 2023
# 03:12
# F9 B5
# CCSFS
# Starlink Group 6–14
# Starlink Group 6–14
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 255
# 12 September 2023
# 06:57
# F9 B5
# VSFB
# Starlink Group 7-2
# Starlink Group 7-2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 256
# 16 September 2023
# 03:38
# F9 B5
# CCSFS
# Starlink Group 6–16
# Starlink Group 6–16
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 257
# 20 September 2023
# 03:38
# F9 B5
# CCSFS
# Starlink Group 6–17
# Starlink Group 6–17
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 258
# 24 September 2023
# 03:38
# F9 B5
# CCSFS
# Starlink Group 6–18
# Starlink Group 6–18
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 259
# 25 September 2023
# 08:48
# F9 B5
# VSFB
# Starlink Group 7-3
# Starlink Group 7-3
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 260
# 30 September 2023
# 02:00
# F9 B5
# CCSFS
# Starlink Group 6–19
# Starlink Group 6–19
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 261
# 5 October 2023
# 05:36
# F9 B5
# CCSFS
# Starlink Group 6–21
# Starlink Group 6–21
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 262
# 9 October 2023
# 07:23
# F9 B5
# VSFB
# Starlink Group 7-4
# Starlink Group 7-4
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 263
# 13 October 2023
# 23:01
# F9 B5
# CCSFS
# Starlink Group 6–22
# Starlink Group 6–22
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 264
# 18 October 2023
# 00:39
# F9 B5
# CCSFS
# Starlink Group 6–23
# Starlink Group 6–23
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 265
# 21 October 2023
# 08:23
# F9 B5
# VSFB
# Starlink Group 7-5
# Starlink Group 7-5
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 266
# 22 October 2023
# 02:17
# F9 B5
# CCSFS
# Starlink Group 6–24
# Starlink Group 6–24
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 267
# 29 October 2023
# 09:00
# F9 B5
# VSFB
# Starlink Group 7-6
# Starlink Group 7-6
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 268
# 30 October 2023
# 23:20
# F9 B5
# CCSFS
# Starlink Group 6–25
# Starlink Group 6–25
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 269
# 4 November 2023
# 00:37
# F9 B5
# CCSFS
# Starlink Group 6–26
# Starlink Group 6–26
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 270
# 8 November 2023
# 05:05
# F9 B5
# CCSFS
# Starlink Group 6–27
# Starlink Group 6–27
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 271
# 10 November 2023
# 01:28
# F9 B5
# KSC
# SpaceX CRS-29
# SpaceX CRS-29
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 272
# 11 November 2023
# 18:49
# F9 B5
# VSFB
# None
# None
# SSO
# Success
#
# Success
# 273
# 12 November 2023
# 21:08
# F9 B5
# CCSFS
# O3b mPOWER
# O3b mPOWER
# MEO
# <a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# Success
#
# Success
# 274
# 18 November 2023
# 05:05
# F9 B5
# CCSFS
# Starlink Group 6–28
# Starlink Group 6–28
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 275
# 20 November 2023
# 10:30
# F9 B5
# VSFB
# Starlink Group 7-7
# Starlink Group 7-7
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 276
# 22 November 2023
# 07:47
# F9 B5
# CCSFS
# Starlink Group 6–29
# Starlink Group 6–29
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 277
# 28 November 2023
# 04:20
# F9 B5
# CCSFS
# Starlink Group 6–30
# Starlink Group 6–30
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 278
# 1 December 2023
# 18:19
# F9 B5
# VSFB
# [227]
# [227]
# SSO
# <a href="/wiki/Republic_of_Korea_Armed_Forces" title="Republic of Korea Armed Forces">Republic of Korea Armed Forces</a>
# Success
#
# Success
# 279
# 3 December 2023
# 04:00
# F9 B5
# CCSFS
# Starlink Group 6–31
# Starlink Group 6–31
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 280
# 7 December 2023
# 05:07
# F9 B5
# CCSFS
# Starlink Group 6–33
# Starlink Group 6–33
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 281
# 8 December 2023
# 08:03
# F9 B5
# VSFB
# Starlink Group 7–8
# Starlink Group 7–8
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 282
# 19 December 2023
# 04:01
# F9 B5
# CCSFS
# Starlink Group 6–34
# Starlink Group 6–34
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 283
# 23 December 2023
# 05:33
# F9 B5
# CCSFS
# Starlink Group 6–32
# Starlink Group 6–32
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Partial failure
# 284
# 24 December 2023
# 13:11
# F9 B5
# VSFB
# SARah
# SARah
# SSO
# <a href="/wiki/Federal_Intelligence_Service" title="Federal Intelligence Service">German Intelligence Service</a>
# Success
#
# Success
# 285
# 29 December 2023
# 04:01
# F9 B5
# CCSFS
# Starlink Group 6–36
# Starlink Group 6–36
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 286
# 3 January 2024
# 03:44
# F9 B5
# VSFB
# Starlink Group 7–9
# Starlink Group 7–9
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 287
# 3 January 2024
# 23:04
# F9 B5
# CCSFS
# Ovzon-3
# Ovzon-3
# GTO
# <a href="/wiki/Ovzon" title="Ovzon">Ovzon</a>
# Success
#
# Success
# 288
# 7 January 2024
# 22:35
# F9 B5
# CCSFS
# Starlink Group 6–35
# Starlink Group 6–35
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 289
# 14 January 2024
# 08:59
# F9 B5
# VSFB
# Starlink Group 7–10
# Starlink Group 7–10
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 290
# 15 January 2024
# 01:52
# F9 B5
# CCSFS
# Starlink Group 6–37
# Starlink Group 6–37
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 291
# 18 January 2024
# 21:49
# F9 B5
# KSC
# Ax-3
# Ax-3
# LEO
# <a href="/wiki/Axiom_Space" title="Axiom Space">Axiom Space</a>
# Success
#
# Success
# 292
# 24 January 2024
# 00:35
# F9 B5
# VSFB
# Starlink Group 7–11
# Starlink Group 7–11
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 293
# 29 January 2024
# 01:10
# F9 B5
# KSC
# Starlink Group 6–38
# Starlink Group 6–38
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 294
# 29 January 2024
# 05:57
# F9 B5
# VSFB
# Starlink Group 7–12
# Starlink Group 7–12
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 295
# 30 January 2024
# 17:07
# F9 B5
# CCSFS
# CRS NG-20
# CRS NG-20
# LEO
# <a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a>
# Success
#
# Success
# 296
# 8 February 2024
# 06:33
# F9 B5
# CCSFS
# PACE
# PACE
# SSO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 297
# 10 February 2024
# 00:34
# F9 B5
# VSFB
# Starlink Group 7–13
# Starlink Group 7–13
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 298
# 14 February 2024
# 22:30
# F9 B5
# CCSFS
# SDA
# SDA
# LEO
# <a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# Success
#
# Success
# 299
# 15 February 2024
# 06:05
# F9 B5
# KSC
# IM-1
# IM-1
# TLI
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 300
# 15 February 2024
# 21:34
# F9 B5
# VSFB
# Starlink Group 7–14
# Starlink Group 7–14
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 301
# 20 February 2024
# 20:11
# F9 B5
# CCSFS
# Merah Putih 2 / Telkomsat HTS 113BT
# Merah Putih 2 / Telkomsat HTS 113BT
# GTO
# <a href="/wiki/Telkom_Indonesia" title="Telkom Indonesia">Telkom Indonesia</a>
# Success
#
# Success
# 302
# 23 February 2024
# 04:11
# F9 B5
# VSFB
# Starlink Group 7–15
# Starlink Group 7–15
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 303
# 25 February 2024
# 22:06
# F9 B5
# CCSFS
# Starlink Group 6–39
# Starlink Group 6–39
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 304
# 29 February 2024
# 15:30
# F9 B5
# CCSFS
# Starlink Group 6–40
# Starlink Group 6–40
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 305
# 4 March 2024
# 03:53
# F9 B5
# KSC
# Crew-8
# Crew-8
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 306
# 4 March 2024
# 22:05
# F9 B5
# VSFB
# None
# None
# SSO
# Success
#
# Success
# 307
# 4 March 2024
# 23:56
# F9 B5
# CCSFS
# Starlink Group 6–41
# Starlink Group 6–41
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 308
# 10 March 2024
# 23:05
# F9 B5
# CCSFS
# Starlink Group 6–43
# Starlink Group 6–43
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 309
# 11 March 2024
# 04:09
# F9 B5
# VSFB
# Starlink Group 7–17
# Starlink Group 7–17
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 310
# 16 March 2024
# 00:21
# F9 B5
# KSC
# Starlink Group 6–44
# Starlink Group 6–44
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 311
# 19 March 2024
# 02:28
# F9 B5
# VSFB
# Starlink Group 7–16
# Starlink Group 7–16
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 312
# 21 March 2024
# 20:55
# F9 B5
# CCSFS
# SpaceX CRS-30
# SpaceX CRS-30
# LEO
# <a href="/wiki/NASA" title="NASA">NASA</a>
# Success
#
# Success
# 313
# 24 March 2024
# 03:09
# F9 B5
# KSC
# Starlink Group 6–42
# Starlink Group 6–42
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 314
# 25 March 2024
# 23:42
# F9 B5
# CCSFS
# Starlink Group 6–46
# Starlink Group 6–46
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 315
# 30 March 2024
# 21:52
# F9 B5
# KSC
# Starlink Group 6–46
# GTO
# <a href="/wiki/Eutelsat" title="Eutelsat">Eutelsat</a>
# Success
#
# Success
# 316
# 31 March 2024
# 01:30
# F9 B5
# CCSFS
# Starlink Group 6–45
# Starlink Group 6–45
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 317
# 2 April 2024
# 02:30
# F9 B5
# VSFB
# Starlink Group 7–18
# Starlink Group 7–18
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 318
# 5 April 2024
# 09:12
# F9 B5
# CCSFS
# Starlink Group 6–47
# Starlink Group 6–47
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 319
# 7 April 2024
# 02:25
# F9 B5
# VSFB
# Starlink Group 8-1
# Starlink Group 8-1
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 320
# 7 April 2024
# 23:16
# F9 B5
# KSC
# Bandwagon-1
# Bandwagon-1
# LEO
# Success
#
# Success
# 321
# 10 April 2024
# 05:40
# F9 B5
# CCSFS
# Starlink Group 6–48
# Starlink Group 6–48
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 322
# 11 April 2024
# 14:25
# F9 B5
# VSFB
# WSF-M 1
# WSF-M 1
# SSO
# <a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# Success
#
# Success
# 323
# 13 April 2024
# 01:40
# F9 B5
# CCSFS
# Starlink Group 6–49
# Starlink Group 6–49
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 324
# 17 April 2024
# 21:26
# F9 B5
# KSC
# Starlink Group 6–51
# Starlink Group 6–51
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 325
# 18 April 2024
# 22:40
# F9 B5
# CCSFS
# Starlink Group 6–52
# Starlink Group 6–52
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 326
# 23 April 2024
# 22:17
# F9 B5
# CCSFS
# Starlink Group 6–53
# Starlink Group 6–53
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 327
# 28 April 2024
# 00:34
# F9 B5
# KSC
# Galileo
# Galileo
# MEO
# <a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# Success
#
# No attempt
#
# 328
# 28 April 2024
# 22:08
# F9 B5
# CCSFS
# Starlink Group 6–54
# Starlink Group 6–54
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 329
# 2 May 2024
# 18:36
# F9 B5
# VSFB
# WorldView Legion 1 & 2
# WorldView Legion 1 & 2
# SSO
# <a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# Success
#
# Success
# 330
# 3 May 2024
# 02:37
# F9 B5
# CCSFS
# Starlink Group 6–55
# Starlink Group 6–55
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 331
# 6 May 2024
# 18:14
# F9 B5
# CCSFS
# Starlink Group 6–57
# Starlink Group 6–57
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 332
# 8 May 2024
# 18:42
# F9 B5
# KSC
# Starlink Group 6–56
# Starlink Group 6–56
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 333
# 10 May 2024
# 04:30
# F9 B5
# VSFB
# Starlink Group 8-2
# Starlink Group 8-2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 334
# 13 May 2024
# 00:53
# F9 B5
# CCSFS
# Starlink Group 6–58
# Starlink Group 6–58
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 335
# 14 May 2024
# 18:39
# F9 B5
# VSFB
# Starlink Group 8-7
# Starlink Group 8-7
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 336
# 18 May 2024
# 00:32
# F9 B5
# CCSFS
# Starlink Group 6–59
# Starlink Group 6–59
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 337
# 22 May 2024
# 08:00
# F9 B5
# VSFB
# Starshield
# Starshield
# LEO
# <a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a>
# Success
#
# Success
# 338
# 23 May 2024
# 02:35
# F9 B5
# CCSFS
# Starlink Group 6–62
# Starlink Group 6–62
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 339
# 24 May 2024
# 02:45
# F9 B5
# KSC
# Starlink Group 6–63
# Starlink Group 6–63
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 340
# 28 May 2024
# 14:24
# F9 B5
# CCSFS
# Starlink Group 6–60
# Starlink Group 6–60
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 341
# 28 May 2024
# 22:20
# F9 B5
# VSFB
# EarthCARE
# EarthCARE
# SSO
# <a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a>
# Success
#
# Success
# 342
# 1 June 2024
# 02:37
# F9 B5
# CCSFS
# Starlink Group 6–64
# Starlink Group 6–64
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 343
# 5 June 2024
# 02:16
# F9 B5
# CCSFS
# Starlink Group 8–5
# Starlink Group 8–5
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 344
# 8 June 2024
# 01:56
# F9 B5
# CCSFS
# Starlink Group 10–1
# Starlink Group 10–1
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 345
# 8 June 2024
# 12:58
# F9 B5
# VSFB
# Starlink Group 8–8
# Starlink Group 8–8
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 346
# 19 June 2024
# 03:40
# F9 B5
# VSFB
# Starlink Group 9–1
# Starlink Group 9–1
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 347
# 20 June 2024
# 21:35
# F9 B5
# CCSFS
# Astra 1P/SES-24
# Astra 1P/SES-24
# GTO
# <a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# Success
#
# Success
# 348
# 23 June 2024
# 17:15
# F9 B5
# CCSFS
# Starlink Group 10–2
# Starlink Group 10–2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 349
# 24 June 2024
# 03:47
# F9 B5
# VSFB
# Starlink Group 9–2
# Starlink Group 9–2
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 350
# 27 June 2024
# 11:14
# F9 B5
# CCSFS
# Starlink Group 10–3
# Starlink Group 10–3
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 351
# 29 June 2024
# 03:14
# F9 B5
# VSFB
# Starshield
# Starshield
# LEO
# <a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a>
# Success
#
# Success
# 352
# 3 July 2024
# 08:55
# F9 B5
# CCSFS
# Starlink Group 8–9
# Starlink Group 8–9
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Success
#
# Success
# 353
# 8 July 2024
# 23:30
# F9 B5
# CCSFS
# Türksat 6A
# Türksat 6A
# GTO
# <a href="/wiki/T%C3%BCrksat_(company)" title="Türksat (company)">Türksat</a>
# Success
#
# Success
# 354
# 12 July 2024
# 02:35
# F9 B5
# VSFB
# Starlink Group 9–3
# Starlink Group 9–3
# LEO
# <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# Failure
#
# Success

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })
df.head()
# Out:
#   Launch site Payload Orbit                Customer Flight No. Payload mass  \
# 0       CCSFS    None   SSO             [Various\n]        195            U
# 1       CCSFS    None   SSO          [[OneWeb], \n]        195            U
# 2       CCSFS    None   SSO  [[USSF], [[[41]]], \n]        195            U
# 3       CCSFS    None   SSO          [[SpaceX], \n]        195            U
# 4       CCSFS    None   SSO          [[SpaceX], \n]        195            U
#
#   Launch outcome Version Booster Booster landing            Date   Time
# 0      Success\n   F9 B5B1060.15         Success  3 January 2023  14:56
# 1      Success\n   F9 B5B1060.15         Success  3 January 2023  14:56
# 2      Success\n   F9 B5B1060.15         Success  3 January 2023  14:56
# 3      Success\n   F9 B5B1060.15         Success  3 January 2023  14:56
# 4      Success\n   F9 B5B1060.15         Success  3 January 2023  14:56

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
